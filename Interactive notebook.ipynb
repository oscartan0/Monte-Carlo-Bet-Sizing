# %%
# cell for analysing the expected results of a series of a select number ofbets of a particular size
# with a particular win probability, over a particular number of simulation
import ipywidgets as widgets
from IPython.display import display
print ("First we look to analyse ")
print("Pick Probability of Winning This Game")
win_prob_slider = widgets.FloatSlider(value=0.55, min=0.5, max=0.8, step=0.01, description="Win Probability")
display(win_prob_slider)
print("Pick the Number of Bets Within this game")
num_bets_slider = widgets.FloatSlider(value=100, min=1, max=1000, step=1, description="# of Bets")
display(num_bets_slider)
print("Pick the Number of Simulations of this Game (we recommend at least 100)"
"(more simulations will produce a more accurate outcome but take longer computing time)")
num_simulations_slider = widgets.FloatSlider(value=1000, min=10, max=10000, step=10, description="# of simulations")
display(num_simulations_slider)
print("pick the size of the bet in dollars, your starting balance will be $100")
bet_size_slider = widgets.FloatSlider(value=1, min=0, max=100, step=0.1, description="Bet Size")
display(bet_size_slider)
# Out:
#   Cell In[2], line 3
#     pip install ipywidgets
#         ^
# SyntaxError: invalid syntax

# %%
#want to return exp value, utility, etc for given values
win_prob = win_prob_slider.value
num_bets = num_bets_slider.value
num_simulations = num_simulations_slider.value
bet_size = bet_size_slider.value
# Out:
# FloatSlider(value=0.46, description='Win Prob', max=0.6, min=0.4, step=0.01)

# %%
# will now set # of simulations permenantly at 1000(0)
# will test optimal bet size (abs)

# %%
# will test optimal bet size (%)

# %%
# we can conclude that bet percentage dominates

# %%
#test effect of number of bets on optimal bet size

# %%
#test effect of probability of winning on optimal bet size
